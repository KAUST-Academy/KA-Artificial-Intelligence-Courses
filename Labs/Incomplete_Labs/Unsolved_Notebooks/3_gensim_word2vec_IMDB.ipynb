# %%
from IPython.display import clear_output

# %%
# %pip install gensim nltk tqdm scikit-learn

# %pip install datasets

clear_output()

# %% [markdown]
# # Content
#
# In this demo, you will train a word2vec(gensim implementation) model on custom data. We will use IMDB dataset as our training data

# %%
import nltk
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity

from datasets import load_dataset


nltk.download('punkt')

clear_output()

# %% [markdown]
# ## Preparing the data

# %%
train_data = load_dataset('imdb', split='train')['text']
train_data = train_data[:500]  # shorten the data because all 25k rows take too long to train

# %%
tokenized_train_data = [word_tokenize(text.lower()) for text in tqdm(train_data, desc='Tokenizing data')]

# %% [markdown]
# ## Train the model
#
# Initialize the model and train it on the data

# %% [markdown]
# ## Try the model
#
# 1. Take a few words spread across some categories(for example you can take a few animals, a few movie genres etc)
# 2. use your model to generate vectors for each of these words
# 4. for each word's vector, calculate it's similarity with all the remaining word's vectors
# 3. for each word, show the most similar word in the remaining list. You can use cosine similarity to find similarity between vectors. higher cosine similarity = more similar. make sure to remove the original word from the list when calculating similarity as a word is always most similar to itself

# %% [markdown]
# ## Finidng similar words
#
# Take a few different words and use your model to find most similar words to it in the corpus. Show the results
