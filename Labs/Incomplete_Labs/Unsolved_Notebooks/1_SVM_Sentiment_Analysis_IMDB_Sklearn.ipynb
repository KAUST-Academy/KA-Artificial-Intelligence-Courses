# %%
from IPython.display import clear_output

# %%
# %pip install torchtext scikit-learn nltk tqdm

# %pip install --upgrade portalocker

clear_output()

# %% [markdown]
# # Content
#
# In this demo, you will make an SVM based text sentiment classifier.
#
# Use the IMDB movies review dataset along with sklearn for model training and evaluation
#
# Make sure to show the performance of the model on the test(unseen) data after training

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from torchtext.datasets import IMDB

from tqdm import tqdm

# %% [markdown]
# ## Downloading and preparing the data

# %%
train_data, test_data = IMDB(split=('train', 'test'))

train_data = list(tqdm(train_data, total=25000))
test_data = list(tqdm(test_data, total=25000))

# %%
y_train, X_train = zip(*train_data)
y_test, X_test = zip(*test_data)

# %% [markdown]
# ## Training the model
#
# Use SVC(support vector classifier. You can use Sklearn's implementation) for training.
#
# the labels are:
#
# 1 - Negative
#
# 2 - Positive
#
# We will also use TF-IDF(Use Sklearn, no need to implement it from scratch) instead of word to index to convert our text to numerical form

# %% [markdown]
# ## Testing
#
# Run your model on the test data and report the accuracy and f1 score.
#
# after that, manually write a few good and bad rmovie eviews and run them through your model to see what your model labels them.
